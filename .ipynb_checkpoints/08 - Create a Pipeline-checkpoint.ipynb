# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets; either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.34.0 to work with aizat

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Overwriting diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-data**, which references the location where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-data", type=str, dest='training_data', help='training data')
args = parser.parse_args()
training_data = args.training_data

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_data,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "aizatcluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# The compute will require a Python environment with the necessary package dependencies installed.

# %%
# %%writefile $experiment_folder/experiment_env.yml
# name: experiment_env
# dependencies:
# - python=3.6.2
# - scikit-learn
# - ipykernel
# - matplotlib
# - pandas
# - pip
# - pip:
#   - azureml-defaults
#   - pyarrow
# Out:
# Overwriting diabetes_pipeline/experiment_env.yml

# %% [markdown]
# Now that you have a Conda configuration file, you can create an environment and use it in the run configuration for the pipeline.

# %%
from azureml.core import Environment
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment (from a .yml file)
experiment_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/experiment_env.yml")

# Register the environment 
experiment_env.register(workspace=ws)
registered_env = Environment.get(ws, 'experiment_env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **OutputFileDatasetConfig** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml.data import OutputFileDatasetConfig
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create an OutputFileDatasetConfig (temporary Data Reference) for data passed from step 1 to step 2
prepped_data = OutputFileDatasetConfig("prepped_data")

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-data', prepped_data.as_input()],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [7488245b][f15ae336-d488-4a75-947c-d778d881d427], (This step will run and generate new outputs)
# Created step Train and Register Model [32ebbea3][52d2388b-31d0-4c44-a414-faa7d6f171bf], (This step will run and generate new outputs)
# Submitted PipelineRun 237ec767-a1d9-41fb-b2cd-b64f7c7a649b
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/237ec767-a1d9-41fb-b2cd-b64f7c7a649b?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 237ec767-a1d9-41fb-b2cd-b64f7c7a649b
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/237ec767-a1d9-41fb-b2cd-b64f7c7a649b?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
# PipelineRun Status: Running
#
#
# StepRunId: ff4f01cb-5efa-4e4d-9866-fe256bf3927e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ff4f01cb-5efa-4e4d-9866-fe256bf3927e?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/11/24 01:58:40 Downloading source code...
# 2021/11/24 01:58:41 Finished downloading source code
# 2021/11/24 01:58:41 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/11/24 01:58:41 Successfully set up Docker network: acb_default_network
# 2021/11/24 01:58:41 Setting up Docker configuration...
# 2021/11/24 01:58:42 Successfully set up Docker configuration
# 2021/11/24 01:58:42 Logging in to registry: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io
# 2021/11/24 01:58:43 Successfully logged into e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io
# 2021/11/24 01:58:43 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 01:58:43 Scanning for dependencies...
# 2021/11/24 01:58:43 Successfully scanned dependencies
# 2021/11/24 01:58:43 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# feac53061382: Pull complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# Digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#  ---> 82e13edbc8db
# Step 2/19 : USER root
#  ---> Running in f60cc2c05219
# Removing intermediate container f60cc2c05219
#  ---> d0ba1bf10f48
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in 455a4f138a47
# Removing intermediate container 455a4f138a47
#  ---> 29ec25c5eeb8
# Step 4/19 : WORKDIR /
#  ---> Running in fd7a21340dc1
# Removing intermediate container fd7a21340dc1
#  ---> c270f1ecdaab
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a05a2d51202e
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 38ba938359a9
# Removing intermediate container 38ba938359a9
#  ---> 2cf6a236d4d4
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> f358a6de257f
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in f332ee33e4aa
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# ipython-7.16.1       | 999 KB    |            |   0%
# ipython-7.16.1       | 999 KB    | ########## | 100%
# ipython-7.16.1       | 999 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 185 KB    |            |   0%
# lz4-c-1.9.3          | 185 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ######8    |  69%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# icu-58.2             | 10.5 MB   |            |   0%
# icu-58.2             | 10.5 MB   | #######4   |  75%
# icu-58.2             | 10.5 MB   | ########## | 100%
# icu-58.2             | 10.5 MB   | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# ca-certificates-2021 | 115 KB    |            |   0%
# ca-certificates-2021 | 115 KB    | ########## | 100%
#
# nest-asyncio-1.5.1   | 10 KB     |            |   0%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# libpng-1.6.37        | 278 KB    |            |   0%
# libpng-1.6.37        | 278 KB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 4          |   4%
# mkl-2020.2           | 138.3 MB  | 5          |   5%
# mkl-2020.2           | 138.3 MB  | 7          |   7%
# mkl-2020.2           | 138.3 MB  | 8          |   9%
# mkl-2020.2           | 138.3 MB  | #          |  11%
# mkl-2020.2           | 138.3 MB  | #9         |  19%
# mkl-2020.2           | 138.3 MB  | ##8        |  29%
# mkl-2020.2           | 138.3 MB  | ###8       |  38%
# mkl-2020.2           | 138.3 MB  | ####8      |  48%
# mkl-2020.2           | 138.3 MB  | #####8     |  59%
# mkl-2020.2           | 138.3 MB  | ######7    |  67%
# mkl-2020.2           | 138.3 MB  | #######5   |  75%
# mkl-2020.2           | 138.3 MB  | ########3  |  84%
# mkl-2020.2           | 138.3 MB  | #########1 |  91%
# mkl-2020.2           | 138.3 MB  | #########8 |  99%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# freetype-2.11.0      | 618 KB    |            |   0%
# freetype-2.11.0      | 618 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# libtiff-4.2.0        | 502 KB    |            |   0%
# libtiff-4.2.0        | 502 KB    | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ########3  |  84%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# pillow-8.3.1         | 637 KB    |            |   0%
# pillow-8.3.1         | 637 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.1 MB    |            |   0%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
#
# pcre-8.45            | 207 KB    |            |   0%
# pcre-8.45            | 207 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# parso-0.8.2          | 69 KB     |            |   0%
# parso-0.8.2          | 69 KB     | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ######6    |  66%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# glib-2.63.1          | 2.9 MB    |            |   0%
# glib-2.63.1          | 2.9 MB    | ##6        |  26%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# intel-openmp-2021.4. | 4.2 MB    |            |   0%
# intel-openmp-2021.4. | 4.2 MB    | ########## | 100%
# intel-openmp-2021.4. | 4.2 MB    | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# zeromq-4.3.4         | 331 KB    |            |   0%
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 27 KB     |            |   0%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
#
# lcms2-2.12           | 312 KB    |            |   0%
# lcms2-2.12           | 312 KB    | ########## | 100%
#
# jupyter_client-7.0.6 | 90 KB     |            |   0%
# jupyter_client-7.0.6 | 90 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# prompt-toolkit-3.0.2 | 259 KB    |            |   0%
# prompt-toolkit-3.0.2 | 259 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####       |  41%
# python-3.6.2         | 23.6 MB   | ########6  |  87%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# gst-plugins-base-1.1 | 4.8 MB    |            |   0%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
#
# openjpeg-2.4.0       | 331 KB    |            |   0%
# openjpeg-2.4.0       | 331 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# pygments-2.10.0      | 725 KB    |            |   0%
# pygments-2.10.0      | 725 KB    | ########## | 100%
#
# qt-5.9.6             | 67.3 MB   |            |   0%
# qt-5.9.6             | 67.3 MB   | #6         |  17%
# qt-5.9.6             | 67.3 MB   | ###6       |  36%
# qt-5.9.6             | 67.3 MB   | #####5     |  56%
# qt-5.9.6             | 67.3 MB   | #######2   |  72%
# qt-5.9.6             | 67.3 MB   | ########6  |  86%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# tornado-6.1          | 581 KB    |            |   0%
# tornado-6.1          | 581 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# expat-2.4.1          | 168 KB    |            |   0%
# expat-2.4.1          | 168 KB    | ########## | 100%
#
# jupyter_core-4.8.1   | 74 KB     |            |   0%
# jupyter_core-4.8.1   | 74 KB     | ########## | 100%
#
# wcwidth-0.2.5        | 26 KB     |            |   0%
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# sip-4.19.8           | 274 KB    |            |   0%
# sip-4.19.8           | 274 KB    | ########## | 100%
#
# jedi-0.17.0          | 780 KB    |            |   0%
# jedi-0.17.0          | 780 KB    | ########## | 100%
# jedi-0.17.0          | 780 KB    | ########## | 100%
#
# fontconfig-2.13.1    | 250 KB    |            |   0%
# fontconfig-2.13.1    | 250 KB    | ########## | 100%
#
# pytz-2021.3          | 171 KB    |            |   0%
# pytz-2021.3          | 171 KB    | ########## | 100%
#
# libsodium-1.0.18     | 244 KB    |            |   0%
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# libuuid-1.0.3        | 17 KB     |            |   0%
# libuuid-1.0.3        | 17 KB     | ########## | 100%
#
# pyparsing-3.0.4      | 81 KB     |            |   0%
# pyparsing-3.0.4      | 81 KB     | ########## | 100%
#
# pyqt-5.9.2           | 4.5 MB    |            |   0%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
#
# decorator-5.1.0      | 14 KB     |            |   0%
# decorator-5.1.0      | 14 KB     | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# backcall-0.2.0       | 13 KB     |            |   0%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ######     |  61%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
# libxml2-2.9.12       | 1.2 MB    |            |   0%
# libxml2-2.9.12       | 1.2 MB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# dbus-1.13.18         | 504 KB    |            |   0%
# dbus-1.13.18         | 504 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 181 KB    |            |   0%
# ipykernel-5.3.4      | 181 KB    | ########## | 100%
#
# kiwisolver-1.3.1     | 80 KB     |            |   0%
# kiwisolver-1.3.1     | 80 KB     | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# libxcb-1.14          | 505 KB    |            |   0%
# libxcb-1.14          | 505 KB    | ########## | 100%
#
# matplotlib-3.3.4     | 26 KB     |            |   0%
# matplotlib-3.3.4     | 26 KB     | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# zstd-1.4.9           | 480 KB    |            |   0%
# zstd-1.4.9           | 480 KB    | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# jpeg-9d              | 232 KB    |            |   0%
# jpeg-9d              | 232 KB    | ########## | 100%
#
# wheel-0.37.0         | 33 KB     |            |   0%
# wheel-0.37.0         | 33 KB     | ########## | 100%
#
# libwebp-base-1.2.0   | 437 KB    |            |   0%
# libwebp-base-1.2.0   | 437 KB    | ########## | 100%
#
# traitlets-4.3.3      | 138 KB    |            |   0%
# traitlets-4.3.3      | 138 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# pyzmq-22.2.1         | 454 KB    |            |   0%
# pyzmq-22.2.1         | 454 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.36.0-py3-none-any.whl (3.0 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting azureml-core~=1.36.0
#   Downloading azureml_core-1.36.0.post2-py3-none-any.whl (2.4 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.36.0
#   Downloading azureml_dataset_runtime-1.36.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.2-py3-none-any.whl (38 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Requirement already satisfied: numpy>=1.16.6 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 2)) (1.19.2)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.36.0->azureml-defaults->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 1)) (2.8.2)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.36.0->azureml-defaults->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 1)) (2021.3)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.20.1-py2.py3-none-any.whl (177 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.36.0->azureml-defaults->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 1)) (1.16.0)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.25.0a,>=2.24.0a
#   Downloading azureml_dataprep-2.24.4-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-dataprep-rslex~=2.0.0dev0
#   Downloading azureml_dataprep_rslex-2.0.3-cp36-cp36m-manylinux2010_x86_64.whl (13.1 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting msal<2.0.0,>=1.12.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting msal-extensions~=0.3.0
#   Downloading msal_extensions-0.3.0-py2.py3-none-any.whl (16 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 1)) (58.0.4)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.2-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.36.0->azureml-defaults->-r /azureml-environment-setup/condaenv.zxn7p7mf.requirements.txt (line 1)) (2021.5.30)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.0.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=39d214f70a4c2c0a2fcff8ee901f6356a586dbfef990804e6fae01f7f9624c2a
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=3e01dd92e5d59fa10e0b9e3e8370e30cd72771f7fa07316fb219eb21b14b85d1
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69940 sha256=2f71f4cae54f334af2661cf23ac8420e4b7f3fbe32d9cb6985368690f2702fb3
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, portalocker, oauthlib, msal, zipp, typing-extensions, requests-oauthlib, msal-extensions, isodate, distro, azure-core, msrest, MarkupSafe, importlib-metadata, dotnetcore2, dataclasses, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, Werkzeug, websocket-client, pyopenssl, pyasn1, pyarrow, msrestazure, Jinja2, jeepney, itsdangerous, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, SecretStorage, pathspec, ndg-httpsclient, jsonpickle, jmespath, inference-schema, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 SecretStorage-3.3.1 Werkzeug-2.0.2 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.20.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.36.0.post2 azureml-dataprep-2.24.4 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.0.3 azureml-dataset-runtime-1.36.0 azureml-defaults-1.36.0 azureml-inference-server-http-0.4.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.15.0 charset-normalizer-2.0.7 click-8.0.3 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 cryptography-3.4.8 dataclasses-0.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 idna-3.3 importlib-metadata-4.8.2 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.16.0 msal-extensions-0.3.0 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pathspec-0.9.0 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.21 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 typing-extensions-4.0.0 urllib3-1.26.7 websocket-client-1.2.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container f332ee33e4aa
#  ---> 3e843f1a278a
# Step 9/19 : ENV PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin:$PATH
#  ---> Running in d11a921eba8e
# Removing intermediate container d11a921eba8e
#  ---> 080fd7c7d95c
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 9215440e379e
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 0054d6e741b0
# Copying environment context
# Removing intermediate container 0054d6e741b0
#  ---> d986e8b46ac7
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 079587147c31
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 5a3c5cecd4e8
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 5a3c5cecd4e8
#  ---> 262c0115a0e1
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in cb7bc55e2ad9
# Removing intermediate container cb7bc55e2ad9
#  ---> 1ef14e915ea7
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib:$LD_LIBRARY_PATH
#  ---> Running in 299437d906e7
# Removing intermediate container 299437d906e7
#  ---> e32901dd0318
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 6c6bdf7d1d48
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in f8ed4fab3042
# Removing intermediate container f8ed4fab3042
#  ---> 0368eba3fed2
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 9c355c4e237e
# Removing intermediate container 9c355c4e237e
#  ---> 2aeb2b07119c
# Step 19/19 : CMD ["bash"]
#  ---> Running in 599a28156f11
# Removing intermediate container 599a28156f11
#  ---> 9e5f2b6529c1
# Successfully built 9e5f2b6529c1
# Successfully tagged e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:latest
# Successfully tagged e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:1
# 2021/11/24 02:01:05 Successfully executed container: acb_step_0
# 2021/11/24 02:01:05 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 02:01:05 Pushing image: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:1, attempt 1
# The push refers to repository [e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25]
# 40e15091b814: Preparing
# de075580b6c4: Preparing
# fef23e845505: Preparing
# 30b24e1eac66: Preparing
# 43deb1be8088: Preparing
# 9c11f9caed87: Preparing
# 028d1bced306: Preparing
# 1b576a95660e: Preparing
# 9dc9676dd617: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# 9c11f9caed87: Waiting
# 028d1bced306: Waiting
# 1b576a95660e: Waiting
# 9dc9676dd617: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# fef23e845505: Pushed
# 30b24e1eac66: Pushed
# 9c11f9caed87: Pushed
# 40e15091b814: Pushed
# de075580b6c4: Pushed
# 1b576a95660e: Pushed
# 9dc9676dd617: Pushed
# 028d1bced306: Pushed
# 9398792c8299: Pushed
# 93c9ec44fed0: Pushed
# e0ae5bb40eae: Pushed
# 5e9c7e64af11: Pushed
# 94c0f7816c07: Pushed
# accea658c5be: Pushed
# 21639b09744f: Pushed
# 20e11b7f408c: Pushed
# c96f19f3c075: Pushed
# 43deb1be8088: Pushed
# 1: digest: sha256:87e18eb076fc4838282c587b339696639c7469179b35f19acb34a6626d8225ab size: 4099
# 2021/11/24 02:03:09 Successfully pushed image: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:1
# 2021/11/24 02:03:09 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 02:03:09 Pushing image: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:latest, attempt 1
# The push refers to repository [e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25]
# 40e15091b814: Preparing
# de075580b6c4: Preparing
# fef23e845505: Preparing
# 30b24e1eac66: Preparing
# 43deb1be8088: Preparing
# 9c11f9caed87: Preparing
# 028d1bced306: Preparing
# 1b576a95660e: Preparing
# 9dc9676dd617: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# 9c11f9caed87: Waiting
# 028d1bced306: Waiting
# 1b576a95660e: Waiting
# 93c9ec44fed0: Waiting
# 9dc9676dd617: Waiting
# 9398792c8299: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# accea658c5be: Waiting
# 20e11b7f408c: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# 94c0f7816c07: Waiting
# 30b24e1eac66: Layer already exists
# 40e15091b814: Layer already exists
# 43deb1be8088: Layer already exists
# de075580b6c4: Layer already exists
# fef23e845505: Layer already exists
# 028d1bced306: Layer already exists
# 9c11f9caed87: Layer already exists
# 9dc9676dd617: Layer already exists
# 9398792c8299: Layer already exists
# e0ae5bb40eae: Layer already exists
# 93c9ec44fed0: Layer already exists
# 1b576a95660e: Layer already exists
# 5e9c7e64af11: Layer already exists
# 94c0f7816c07: Layer already exists
# accea658c5be: Layer already exists
# 20e11b7f408c: Layer already exists
# c96f19f3c075: Layer already exists
# 21639b09744f: Layer already exists
# latest: digest: sha256:87e18eb076fc4838282c587b339696639c7469179b35f19acb34a6626d8225ab size: 4099
# 2021/11/24 02:03:11 Successfully pushed image: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:latest
# 2021/11/24 02:03:11 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 142.035562)
# 2021/11/24 02:03:11 Populating digests for step ID: acb_step_0...
# 2021/11/24 02:03:12 Successfully populated digests for step ID: acb_step_0
# 2021/11/24 02:03:12 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 124.509627)
# 2021/11/24 02:03:12 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.333247)
# 2021/11/24 02:03:12 The following dependencies were found:
# 2021/11/24 02:03:12
# - image:
#     registry: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io
#     repository: azureml/azureml_21ec214220b650a356d20fde58334d25
#     tag: latest
#     digest: sha256:87e18eb076fc4838282c587b339696639c7469179b35f19acb34a6626d8225ab
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
# - image:
#     registry: e9fffeb0c22141e5b83e69411eeb42cd.azurecr.io
#     repository: azureml/azureml_21ec214220b650a356d20fde58334d25
#     tag: "1"
#     digest: sha256:87e18eb076fc4838282c587b339696639c7469179b35f19acb34a6626d8225ab
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
#
#
# Run ID: cm2 was successful after 4m33s
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
#
# Warnings:
# This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"
# {'runId': 'ff4f01cb-5efa-4e4d-9866-fe256bf3927e', 'target': 'aizatcluster', 'status': 'Completed', 'startTimeUtc': '2021-11-24T02:06:14.629516Z', 'endTimeUtc': '2021-11-24T02:07:57.583616Z', 'services': {}, 'warnings': [{'message': 'This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"'}], 'properties': {'ContentSnapshotId': 'd69c9ab1-a142-4c6c-af7c-dba3d62e8598', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'f15ae336-d488-4a75-947c-d778d881d427', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '7488245b', 'azureml.pipelinerunid': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.pipeline': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'ea243bb8-a333-4c3c-8861-4bdb3bdac575'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': '30e92b1f-3515-4d8d-acb1-245ce58c8dd0'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'prepped_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/ff4f01cb-5efa-4e4d-9866-fe256bf3927e/prepped_data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "30e92b1f-3515-4d8d-acb1-245ce58c8dd0",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='aizat', subscription_id='c4c2069d-4c83-47fb-b6c7-41298aa69933', resource_group='aizat')"
#   }
# }}], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', 'DatasetOutputConfig:prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aizatcluster', 'dataReferences': {}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'ea243bb8-a333-4c3c-8861-4bdb3bdac575', 'name': None, 'version': '2'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'prepped_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}], 'name': 'azureml_0c5a9aa2def4b3c2501c1f40287a356b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.ff4f01cb-5efa-4e4d-9866-fe256bf3927e/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=5iUQpPItuQ7dztJ1zmLrg5mGXt1FFbTyRvo3H9vQ9x8%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A06%3A09Z&ske=2021-11-25T09%3A16%3A09Z&sks=b&skv=2019-07-07&st=2021- ...
# StepRunId: c9db8be1-ae72-47a7-a6da-182888d47f4d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c9db8be1-ae72-47a7-a6da-182888d47f4d?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
# StepRun( Train and Register Model ) Status: Running
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
#
# Warnings:
# This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"
# {'runId': 'c9db8be1-ae72-47a7-a6da-182888d47f4d', 'target': 'aizatcluster', 'status': 'Completed', 'startTimeUtc': '2021-11-24T02:08:43.393143Z', 'endTimeUtc': '2021-11-24T02:09:07.712082Z', 'services': {}, 'warnings': [{'message': 'This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"'}], 'properties': {'ContentSnapshotId': 'd69c9ab1-a142-4c6c-af7c-dba3d62e8598', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '52d2388b-31d0-4c44-a414-faa7d6f171bf', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '32ebbea3', 'azureml.pipelinerunid': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.pipeline': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '30e92b1f-3515-4d8d-acb1-245ce58c8dd0'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_2db29abe', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-data', 'DatasetConsumptionConfig:input_2db29abe'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aizatcluster', 'dataReferences': {}, 'data': {'input_2db29abe': {'dataLocation': {'dataset': {'id': '30e92b1f-3515-4d8d-acb1-245ce58c8dd0', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_2db29abe', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}], 'name': 'azureml_0c5a9aa2def4b3c2501c1f40287a356b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicati ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'status': 'Completed', 'startTimeUtc': '2021-11-24T01:58:32.079575Z', 'endTimeUtc': '2021-11-24T02:09:08.906112Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.237ec767-a1d9-41fb-b2cd-b64f7c7a649b/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=FU%2F0rXOQk6XYXVSVfOZTGfoJ1pRXyf3IJxl2xUv88U8%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A04%3A42Z&ske=2021-11-25T09%3A14%3A42Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A10Z&se=2021-11-24T10%3A09%3A10Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.237ec767-a1d9-41fb-b2cd-b64f7c7a649b/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=pyGHR23XFhFcI5IRd%2BxnSyJJwSqbh2SpWHQnBohWwrU%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A04%3A42Z&ske=2021-11-25T09%3A14%3A42Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A10Z&se=2021-11-24T10%3A09%3A10Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.237ec767-a1d9-41fb-b2cd-b64f7c7a649b/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=QjZE9Wx%2FFB8%2Fsv15lZbF3cLA2DQfhVBz17N6nG2H3Mw%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A04%3A42Z&ske=2021-11-25T09%3A14%3A42Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A10Z&se=2021-11-24T10%3A09%3A10Z&sp=r'}, 'submittedBy': 'Ahmad Aizat Rosli'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.9004444444444445
# 	 AUC : 0.8862361650715226
# 	 ROC : aml://artifactId/ExperimentRun/dcid.c9db8be1-ae72-47a7-a6da-182888d47f4d/ROC_1637719738.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 5
# 	 Training context : Pipeline
# 	 AUC : 0.8862361650715226
# 	 Accuracy : 0.9004444444444445
#
#
# diabetes_model version: 4
# 	 Training context : File dataset
# 	 AUC : 0.8468331741963582
# 	 Accuracy : 0.7793333333333333
#
#
# diabetes_model version: 3
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568509052814499
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# amlstudio-designer-predict-dia version: 1
# 	 CreatedByAMLStudio : true
#
#
# AutoML7001303fd0 version: 1

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: 4a33dc1b-769f-4913-8ff4-311be15990cf,
# Status: Active,
# Endpoint: https://southeastasia.api.azureml.ms/pipelines/v1.0/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourceGroups/aizat/providers/Microsoft.MachineLearningServices/workspaces/aizat/PipelineRuns/PipelineSubmit/4a33dc1b-769f-4913-8ff4-311be15990cf)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://southeastasia.api.azureml.ms/pipelines/v1.0/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourceGroups/aizat/providers/Microsoft.MachineLearningServices/workspaces/aizat/PipelineRuns/PipelineSubmit/4a33dc1b-769f-4913-8ff4-311be15990cf

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'b9afa80c-afa3-46a6-86bd-9aee2a2307ef'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: b9afa80c-afa3-46a6-86bd-9aee2a2307ef
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/b9afa80c-afa3-46a6-86bd-9aee2a2307ef?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
# PipelineRun Status: Running
#
#
# StepRunId: dd01ae77-b5c6-4564-824b-daec404599d7
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/dd01ae77-b5c6-4564-824b-daec404599d7?wsid=/subscriptions/c4c2069d-4c83-47fb-b6c7-41298aa69933/resourcegroups/aizat/workspaces/aizat&tid=2d07553d-48db-40a4-8c97-f678a5e3cb49
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': 'dd01ae77-b5c6-4564-824b-daec404599d7', 'target': 'aizatcluster', 'status': 'Completed', 'startTimeUtc': '2021-11-24T02:09:24.419661Z', 'endTimeUtc': '2021-11-24T02:09:24.483785Z', 'services': {}, 'properties': {'azureml.reusedrunid': 'ff4f01cb-5efa-4e4d-9866-fe256bf3927e', 'azureml.reusednodeid': '7488245b', 'azureml.reusedpipeline': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.reusedpipelinerunid': '237ec767-a1d9-41fb-b2cd-b64f7c7a649b', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '7488245b', 'ContentSnapshotId': 'd69c9ab1-a142-4c6c-af7c-dba3d62e8598', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'f15ae336-d488-4a75-947c-d778d881d427', 'azureml.pipeline': 'b9afa80c-afa3-46a6-86bd-9aee2a2307ef', 'azureml.pipelinerunid': 'b9afa80c-afa3-46a6-86bd-9aee2a2307ef', 'azureml.pipelineid': '4a33dc1b-769f-4913-8ff4-311be15990cf', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', 'DatasetOutputConfig:prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aizatcluster', 'dataReferences': {}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'ea243bb8-a333-4c3c-8861-4bdb3bdac575', 'name': None, 'version': '2'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'prepped_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}], 'name': 'azureml_0c5a9aa2def4b3c2501c1f40287a356b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlI ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'b9afa80c-afa3-46a6-86bd-9aee2a2307ef', 'status': 'Completed', 'startTimeUtc': '2021-11-24T02:09:23.288512Z', 'endTimeUtc': '2021-11-24T02:09:25.044819Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelineid': '4a33dc1b-769f-4913-8ff4-311be15990cf'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=Y18In7boOc3OIcBsLx9p3NHwYnM6A6t1h2zh4PuCRfk%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=l4XLImrMi5zj%2FVKIq%2BzqOOJ%2BuxOpKuJaHV2Qt58UfiE%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=gj4Wlmu%2FiOsmoS44EUHE1WK10DFwK6ho0WJ4PxW8DJA%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r'}, 'submittedBy': 'Ahmad Aizat Rosli'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: 7544e882-1f92-4ca6-8532-17c1b1ac8072,
#  Status: Active,
#  Pipeline Id: 4a33dc1b-769f-4913-8ff4-311be15990cf,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': 'b9afa80c-afa3-46a6-86bd-9aee2a2307ef',
#  'status': 'Completed',
#  'startTimeUtc': '2021-11-24T02:09:23.288512Z',
#  'endTimeUtc': '2021-11-24T02:09:25.044819Z',
#  'services': {},
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'HTTP',
#   'azureml.parameters': '{}',
#   'azureml.continue_on_step_failure': 'False',
#   'azureml.pipelineComponent': 'pipelinerun',
#   'azureml.pipelineid': '4a33dc1b-769f-4913-8ff4-311be15990cf'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=Y18In7boOc3OIcBsLx9p3NHwYnM6A6t1h2zh4PuCRfk%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=l4XLImrMi5zj%2FVKIq%2BzqOOJ%2BuxOpKuJaHV2Qt58UfiE%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://aizat4264732956.blob.core.windows.net/azureml/ExperimentRun/dcid.b9afa80c-afa3-46a6-86bd-9aee2a2307ef/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=gj4Wlmu%2FiOsmoS44EUHE1WK10DFwK6ho0WJ4PxW8DJA%3D&skoid=8a25a25e-a5bc-4faa-8ad7-859cd24347df&sktid=2d07553d-48db-40a4-8c97-f678a5e3cb49&skt=2021-11-24T01%3A35%3A48Z&ske=2021-11-25T09%3A45%3A48Z&sks=b&skv=2019-07-07&st=2021-11-24T01%3A59%3A27Z&se=2021-11-24T10%3A09%3A27Z&sp=r'},
#  'submittedBy': 'Ahmad Aizat Rosli'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
